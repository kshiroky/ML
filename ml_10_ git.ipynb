# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression as logreg
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.svm import LinearSVC as linmach
from sklearn.ensemble import BaggingClassifier as bagg
from sklearn.ensemble import RandomForestClassifier as forest
from sklearn.ensemble import StackingClassifier as stack
import os
import cv2 as cv

# %%
#введите путь к папке с картинками
path = ''
raw_data = os.listdir(path)
data = sorted(raw_data)
data.pop(0)
# Out:
# '.DS_Store'

# %%
#фукнция для перевода картинок в гистограмму (цифры)
#строка imag = cv.imread(image) обязательна (чтение изображения) 
def extract_histogram(image):
    imag = cv.imread(image)
    im = cv.calcHist([imag], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    im_final = np.reshape(im, [512, 1])
    cv.normalize(im_final, im_final)
    return im_final.flatten()

# %%
#сформируем словарь с гистограммами каждого изображения
hist_dict = {}
for each in data:
    p = path + '/' + each
    hist = extract_histogram(p)
    hist_dict[each] = hist

# %%
#назначим классы для каждой картинки (cat - 0, dog - 1)
cat_label = {}
dog_label = {}
for each in data:
    if 'cat' in each:
        cat_label[each] = 0
    elif 'dog' in each:
        dog_label[each] = 1

# %%
#сформируем табличку с данными для обучения модели
train_data = pd.DataFrame(hist_dict)
train_data = train_data.transpose()

label_ser = pd.Series(cat_label, name = 'label')
dog_ser = pd.Series(dog_label, name = 'label')
label_ser = label_ser.append(dog_ser)
train_data = train_data.merge(label_ser, right_index = True, left_index = True)
train_data
# Out:
#                     0         1         2         3         4    5    6    7  \
# cat.0.jpg    0.242645  0.073122  0.000232  0.000000  0.000000  0.0  0.0  0.0
# cat.1.jpg    0.418818  0.126781  0.000085  0.000000  0.000000  0.0  0.0  0.0
# cat.10.jpg   0.356737  0.184168  0.020616  0.001619  0.000717  0.0  0.0  0.0
# cat.100.jpg  0.001266  0.019995  0.011941  0.001583  0.000158  0.0  0.0  0.0
# cat.101.jpg  0.000000  0.000105  0.000000  0.000000  0.000000  0.0  0.0  0.0
# ...               ...       ...       ...       ...       ...  ...  ...  ...
# dog.95.jpg   0.134753  0.010071  0.000000  0.000000  0.000000  0.0  0.0  0.0
# dog.96.jpg   0.122335  0.165961  0.041414  0.016499  0.000102  0.0  0.0  0.0
# dog.97.jpg   0.081336  0.033835  0.000000  0.000000  0.000000  0.0  0.0  0.0
# dog.98.jpg   0.598071  0.090467  0.006297  0.000019  0.000000  0.0  0.0  0.0
# dog.99.jpg   0.501765  0.108061  0.017979  0.003817  0.000026  0.0  0.0  0.0
#
#                     8         9  ...       503  504       505     506  \
# cat.0.jpg    0.000000  0.087363  ...  0.000000  0.0  0.000000  0.0000
# cat.1.jpg    0.005085  0.076441  ...  0.000000  0.0  0.000000  0.0000
# cat.10.jpg   0.000041  0.027440  ...  0.000000  0.0  0.000000  0.0000
# cat.100.jpg  0.000000  0.002145  ...  0.002233  0.0  0.000000  0.0000
# cat.101.jpg  0.000000  0.000366  ...  0.000000  0.0  0.002719  0.7748
# ...               ...       ...  ...       ...  ...       ...     ...
# dog.95.jpg   0.004053  0.041960  ...  0.005025  0.0  0.000000  0.0000
# dog.96.jpg   0.000991  0.147656  ...  0.000000  0.0  0.000000  0.0000
# dog.97.jpg   0.000000  0.006635  ...  0.002249  0.0  0.000000  0.0000
# dog.98.jpg   0.000019  0.037595  ...  0.000190  0.0  0.000000  0.0000
# dog.99.jpg   0.004291  0.051911  ...  0.000369  0.0  0.000000  0.0000
#
#                  507       508       509       510       511  label
# cat.0.jpg    0.00000  0.000000  0.000000  0.000000  0.000000      0
# cat.1.jpg    0.00000  0.000000  0.000000  0.000042  0.000000      0
# cat.10.jpg   0.00000  0.000000  0.000000  0.000000  0.007726      0
# cat.100.jpg  0.00000  0.000000  0.000000  0.023354  0.497077      0
# cat.101.jpg  0.34338  0.038583  0.114442  0.126833  0.008469      0
# ...              ...       ...       ...       ...       ...    ...
# dog.95.jpg   0.00000  0.000000  0.000000  0.012636  0.010754      1
# dog.96.jpg   0.00000  0.000000  0.000000  0.000000  0.000000      1
# dog.97.jpg   0.00000  0.000000  0.000000  0.004499  0.228866      1
# dog.98.jpg   0.00000  0.000000  0.000000  0.000000  0.010350      1
# dog.99.jpg   0.00000  0.000000  0.000000  0.000026  0.001343      1
#
# [1000 rows x 513 columns]

# %%
#разделим данные на набор предикторов x_train и отклик y_train
x_train = train_data.drop(['label'], axis = 1)
y_train = train_data.label

# %%
# обучим LinearSVC (корректируйте параметры классификатора в соответствие с заданием)
svc_clf = linmach(C = 1.64, random_state = 414)
train_svc = svc_clf.fit(x_train, y_train)

# %%
#обучим бэггинг деревьев принятия решения (корректируйте параметры классификатора в соответствие с заданием)
bagg_clf = bagg(base_estimator = dtc(criterion = 'entropy', min_samples_leaf = 10, max_leaf_nodes = 20, random_state = 414), n_estimators = 20, random_state = 414)
train_bagg = bagg_clf.fit(x_train, y_train)

# %%
#обучим лес принятия решений (корректируйте параметры классификатора в соответствие с заданием)
rand_for_clf = forest(n_estimators = 20, criterion = 'entropy', min_samples_leaf = 10, max_leaf_nodes = 20, random_state = 414)
train_forest = rand_for_clf.fit(x_train, y_train)

# %%
#обучим логистическую регрессию (корректируйте параметры классификатора в соответствие с заданием)
log_clf = logreg(solver = 'lbfgs', random_state = 414)
train_log = log_clf.fit(x_train, y_train)

# %%
#соберем все в стэкинг (корректируйте параметр cv по заданию)
estims = [train_svc, train_bagg, train_forest]
estims2 = [('svc', svc_clf), ('bagg' ,bagg_clf), ('forest', rand_for_clf)]
stack_clf = stack(estimators = estims2 , final_estimator = log_clf, cv = 2)

# %%
#обучим модель стэкинга
res = stack_clf.fit(x_train, y_train)
res
# Out:
# StackingClassifier(cv=2,
#                    estimators=[('svc', LinearSVC(C=1.64, random_state=414)),
#                                ('bagg',
#                                 BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                                         max_leaf_nodes=20,
#                                                                                         min_samples_leaf=10,
#                                                                                         random_state=414),
#                                                   n_estimators=20,
#                                                   random_state=414)),
#                                ('forest',
#                                 RandomForestClassifier(criterion='entropy',
#                                                        max_leaf_nodes=20,
#                                                        min_samples_leaf=10,
#                                                        n_estimators=20,
#                                                        random_state=414))],
#                    final_estimator=LogisticRegression(random_state=414))

# %%
#найдем точность
accuracy = res.score(x_train, y_train)
accuracy
# Out:
# 0.849

# %%
#путь к тестовой выборке
path_test = ''
data_test = os.listdir(path_test)
data_test = sorted(data_test)
data_test.pop(0)
data_test.pop(0)
# Out:
# '.ipynb_checkpoints'

# %%
#словарь с гистограммами для тестовой выборки
test_dict = {}
for each in data_test:
    p = path_test + '/' + each
    im = extract_histogram(p)
    test_dict[each] = im

# %%
#назанчение классов для тестовой выборки
cat_test = {}
dog_test = {}
for each in data_test:
    if 'cat' in each:
        cat_test[each] = 0
    elif 'dog' in each:
        dog_test[each] = 1

# %%
#колонка с классами для всех объектов в тестовой выборке
label_test = pd.Series(cat_test, name = 'label')
dogggg = pd.Series(dog_test, name = 'label')
label_test = label_test.append(dogggg)

# %%
#итоговая таблица для объектов тестовой выборки
df_test = pd.DataFrame(test_dict)
df_test = df_test.transpose()
df_test = df_test.merge(label_test, right_index = True, left_index = True)

# %%
#сюда запишите названия файлов для оценки (из задания)
name = ['cat.1042.jpg', 'cat.1019.jpg', 'dog.1019.jpg', 'dog.1012.jpg']

# %%
#таблица с данными объектов для оценки
df_to_test = pd.DataFrame(df_test.loc[name])
df_to_test
# Out:
#                      0         1         2         3         4         5  \
# cat.1042.jpg  0.288885  0.000000  0.000000  0.000000  0.000000  0.000000
# cat.1019.jpg  0.018413  0.022763  0.000551  0.000000  0.000000  0.000000
# dog.1019.jpg  0.293502  0.003384  0.001184  0.001988  0.001311  0.000000
# dog.1012.jpg  0.561123  0.209176  0.024570  0.032206  0.057108  0.049472
#
#                      6    7         8         9  ...       503  504  505  506  \
# cat.1042.jpg  0.000000  0.0  0.000232  0.000348  ...  0.000155  0.0  0.0  0.0
# cat.1019.jpg  0.000000  0.0  0.000613  0.017218  ...  0.000827  0.0  0.0  0.0
# dog.1019.jpg  0.000000  0.0  0.000296  0.002073  ...  0.000761  0.0  0.0  0.0
# dog.1012.jpg  0.004648  0.0  0.012617  0.187594  ...  0.000000  0.0  0.0  0.0
#
#               507       508       509       510       511  label
# cat.1042.jpg  0.0  0.007069  0.025339  0.067441  0.816325      0
# cat.1019.jpg  0.0  0.000184  0.037347  0.011734  0.036795      0
# dog.1019.jpg  0.0  0.000000  0.000000  0.007191  0.047754      1
# dog.1012.jpg  0.0  0.000000  0.000000  0.000000  0.015605      1
#
# [4 rows x 513 columns]

# %%
#итоговый набор предикторов для оценки
x_to_test = df_to_test.drop(['label'], axis = 1)

# %%
#вероятность отнесения объектов к классу
#если нужен cat, смотрим на первый столбик, если dog - на второй
proba = res.predict_proba(x_to_test)
proba
# Out:
# array([[0.41251386, 0.58748614],
#        [0.53194303, 0.46805697],
#        [0.27992543, 0.72007457],
#        [0.31244582, 0.68755418]])
